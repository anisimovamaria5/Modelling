# %%
import pandas as pd
import numpy as np
from DKS_math.DKS import *
from solver import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from DKS_math.DKS import *
#       4 from solver import *
#
# ModuleNotFoundError: No module named 'DKS_math'

# %%
df_date = pd.read_excel("../media/Показатели для ДКС.xlsx", sheet_name='Лист2')

# %%
bound_dict = {
    'power':(
        np.array([16000, 16000]),
        np.array([7000, 7000]),
        200),
    'comp':(
        np.array([1.9, 1.9]),
        np.array([1, 1]),
        0.01),
    'udal':(
        np.array([100, 100]),
        np.array([0, 0]),
        1.0),    
    'freq_dimm':(
        np.array([1.05, 1.05]),    
        np.array([0.7, 0.7]),
        0.01),
    'p_out':(
        np.array([4.5, 6.5]),    
        np.array([0.1, 0.1]),
        0.1),
    'target':(
        np.array([10, 10]),    
        np.array([-10, -10]),
        0.1),
}
conf_solv_obj = ConfGDHSolver([
        (GdhInstance.create_by_csv('../DKS_math/Test/spch_dimkoef/ГПА-ц3-16С-45-1.7(ККМ).csv'), 4),
        (GdhInstance.create_by_csv('../DKS_math/Test/spch_dimkoef/CGX-425-16-65-1.7СМП(ПСИ).csv'), 4),
        ],
        bound_dict
        )
df_conf = []
df_data_mode = df_date.loc[:23, ('Расход, млн', 'Pвх, бар', 'Pвых,бар', 'T', 'R', 'K')]

q_rates = df_data_mode['Расход, млн']
p_ins = df_data_mode['Pвх, бар']
p_outs = df_data_mode['Pвых,бар']
print(time.strftime('%X'))
beg = dt.now()
# for q_rates, p_ins, p_outs in list(zip(df_data_mode['Расход, млн'], df_data_mode['Pвх, бар'], df_data_mode['Pвых,бар'])):
    # mode = Mode(q_rate, p_in,  288, 512, 1.31, p_out)
    # df = conf_solv_obj.get_calc_work_mode(mode)
    # df_conf.append(df)
modes = [Mode([q_rate, q_rate], p_in, 288, 512, 1.31, p_out, 0.101325, 283) for q_rate, p_in, p_out in zip(q_rates, p_ins, p_outs)]
res = asyncio.run(calc_modes_parall(conf_solv_obj, modes))
res
# df_conf
# df_res = pd.concat(df_conf)
# df_res
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[33], line 44
#      39 # for q_rates, p_ins, p_outs in list(zip(df_data_mode['Расход, млн'], df_data_mode['Pвх, бар'], df_data_mode['Pвых,бар'])):
#      40     # mode = Mode(q_rate, p_in,  288, 512, 1.31, p_out)
#      41     # df = conf_solv_obj.get_calc_work_mode(mode)
#      42     # df_conf.append(df)
#      43 modes = [Mode([q_rate, q_rate], p_in, 288, 512, 1.31, p_out, 0.101325, 283) for q_rate, p_in, p_out in zip(q_rates, p_ins, p_outs)]
# ---> 44 res = asyncio.run(calc_modes_parall(conf_solv_obj, modes))
#      45 res
#      46 # df_conf
#      47 # df_res = pd.concat(df_conf)
#      48 # df_res
#
# File C:\Program Files\Python310\lib\asyncio\runners.py:33, in run(main, debug)
#       9 """Execute the coroutine and return the result.
#      10
#      11 This function runs the passed coroutine, taking care of
#    (...)
#      30     asyncio.run(main())
#      31 """
#      32 if events._get_running_loop() is not None:
# ---> 33     raise RuntimeError(
#      34         "asyncio.run() cannot be called from a running event loop")
#      36 if not coroutines.iscoroutine(main):
#      37     raise ValueError("a coroutine was expected, got {!r}".format(main))
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
import pandas as pd
import numpy as np
df_case = pd.read_excel("../Показатели для ДКС.xlsx", sheet_name='Лист2')
df_data = df_case.loc[:23, ('Pвх, бар', 'Расход, млн', 'Pвых,бар', 'T', 'R', 'K', 'СПЧ',  'Вн. мощность, кВт', 'Степень сжатия, д. ед.', 'Частота, об/мин', 'Начальное давление, МПа', 'Конечное давление, МПа','Кол-ов рабочих нагнетателей, шт')]
df_res_1, df_res_2 = pd.DataFrame(), pd.DataFrame()

for column in df_data.columns[6:]:
    for ind, row in df_data[column].iteritems():
        df_data_values = df_data[column][ind].split('+') 
        df_res_1.at[ind, f'{column}'] = df_data_values[0]
        df_res_2.at[ind, f'{column}'] = df_data_values[1]
df_res = pd.concat([df_res_1, df_res_2], axis=1, keys=[0, 1]).stack()
df_1 = df_res.reset_index()

df_data_2 = df_data.loc[:, ('Расход, млн', 'Pвх, бар', 'Pвых,бар', 'T', 'R', 'K')]
df_data_2.columns = ['Q', 'P_in', 'P_target', 'T', 'R', 'K']
res_df_2 = pd.DataFrame(df_data_2.stack())
df_2 = res_df_2.reset_index()

df_bound = pd.DataFrame({'gpa_max_cnt': [3, 4],
                         'bound_power_max': [16000, 16000],
                         'bound_power_min': [7000, 7000],
                         'bound_comp_max': [1.9, 1.9],
                         'bound_comp_min': [1, 1],
                         'bound_udal_max': [100, 100],
                         'bound_udal_min': [0, 0],                         
                         'bound_freq_max': [1.05, 1.05],
                         'bound_freq_min': [0.7, 0.7],
                         'bound_p_out_max': [4.5, 6.5],
                         'bound_p_out_min': [0.1, 0.1],
                         'bound_target_max': [10, 10],
                         'bound_target_min': [-10, -10],
                         })
df_3 = (pd.concat([df_bound.T]*14, keys=range(0,14))).reset_index()

df_ob = pd.concat([df_2, df_1, df_3], axis=0)
df_result = df_ob.sort_values(by=['level_0', 'level_1'])
df_result = df_result.set_index(['level_0'])

for i in range(14):
    df_t = df_result[df_result.index == i]
    filename = f'case_{i+1}.txt'
    df_t.to_csv(f'./Test/Fixture/{filename}',sep='\t')
# Out:
# C:\Users\M_Anisimova\AppData\Local\Temp\ipykernel_7104\99513578.py:8: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for ind, row in df_data[column].iteritems():
# C:\Users\M_Anisimova\AppData\Local\Temp\ipykernel_7104\99513578.py:8: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for ind, row in df_data[column].iteritems():
# C:\Users\M_Anisimova\AppData\Local\Temp\ipykernel_7104\99513578.py:8: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for ind, row in df_data[column].iteritems():
# C:\Users\M_Anisimova\AppData\Local\Temp\ipykernel_7104\99513578.py:8: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for ind, row in df_data[column].iteritems():
# C:\Users\M_Anisimova\AppData\Local\Temp\ipykernel_7104\99513578.py:8: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for ind, row in df_data[column].iteritems():
# C:\Users\M_Anisimova\AppData\Local\Temp\ipykernel_7104\99513578.py:8: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for ind, row in df_data[column].iteritems():
# C:\Users\M_Anisimova\AppData\Local\Temp\ipykernel_7104\99513578.py:8: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for ind, row in df_data[column].iteritems():

# %%
df_case = pd.read_csv('../DKS_math/Test/Fixture/case_1.txt', sep='\t')
df_case
# Out:
#     level_0                          level_1                       0  \
# 0         0                                K                    1.31
# 1         0                             P_in        3.09655498953779
# 2         0                         P_target        4.52460708334446
# 3         0                                Q        34.6247653881433
# 4         0                                R                   512.0
# 5         0                                T                   288.0
# 6         0                   bound_comp_max                     1.9
# 7         0                   bound_comp_min                     1.0
# 8         0                   bound_freq_max                    1.05
# 9         0                   bound_freq_min                     0.7
# 10        0                  bound_p_out_max                     4.5
# 11        0                  bound_p_out_min                     0.1
# 12        0                  bound_power_max                 16000.0
# 13        0                  bound_power_min                  7000.0
# 14        0                 bound_target_max                    10.0
# 15        0                 bound_target_min                   -10.0
# 16        0                   bound_udal_max                   100.0
# 17        0                   bound_udal_min                     0.0
# 18        0                      gpa_max_cnt                     3.0
# 19        0                Вн. мощность, кВт                   12116
# 20        0  Кол-ов рабочих нагнетателей, шт                       1
# 21        0           Конечное давление, МПа                    3.61
# 22        0          Начальное давление, МПа                     3.1
# 23        0                              СПЧ  ГПА-ц3-16С-45-1.7(ККМ)
# 24        0           Степень сжатия, д. ед.                    1.16
# 25        0                  Частота, об/мин                    4400
#
#                             1
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         1.9
# 7                         1.0
# 8                        1.05
# 9                         0.7
# 10                        6.5
# 11                        0.1
# 12                    16000.0
# 13                     7000.0
# 14                       10.0
# 15                      -10.0
# 16                      100.0
# 17                        0.0
# 18                        4.0
# 19                       7151
# 20                          2
# 21                       4.72
# 22                       3.55
# 23  CGX-425-16-65-1.7СМП(ПСИ)
# 24                       1.33
# 25                       4040

# %%
df_case = pd.read_excel("../Показатели для ДКС.xlsx", sheet_name='Лист2')
df_data = df_case.loc[:23, ('Pвх, бар', 'Расход, млн', 'Pвых,бар', 'T', 'R', 'K', 'СПЧ',  'Вн. мощность, кВт', 'Степень сжатия, д. ед.', 'Частота, об/мин', 'Начальное давление, МПа', 'Конечное давление, МПа','Кол-ов рабочих нагнетателей, шт','Удаленность от точки помпажа, д. ед', 'Объемный расход, м3/мин')]
df_res_1, df_res_2 = pd.DataFrame(), pd.DataFrame()

for column in df_data.columns[6:]:
    for ind, row in df_data[column].iteritems():
        df_data_values = df_data[column][ind].split('+') 
        df_res_1.at[ind, f'{column}'] = df_data_values[0]
        df_res_2.at[ind, f'{column}'] = df_data_values[1]
df_res_case = pd.concat([df_res_1, df_res_2], axis=1, keys=[0, 1]).stack(level=0)
df_res_case
# Out:
#      Вн. мощность, кВт Кол-ов рабочих нагнетателей, шт Конечное давление, МПа  \
# 0  0             12116                               1                   3.61
#    1              7151                               2                   4.72
# 1  0             15333                               1                   3.65
#    1              7483                               2                   4.73
# 2  0              8790                               1                   3.51
#    1              7150                               2                   4.78
# 3  0              7098                               1                   4.04
#    1              7312                               1                   5.15
# 4  0              7146                               1                   4.11
#    1              7011                               1                   5.25
# 5  0              7022                               1                   4.08
#    1              7115                               1                   5.22
# 6  0              7027                               1                   4.17
#    1              7016                               1                   5.44
# 7  0              7073                               1                   4.12
#    1              7065                               1                   5.32
# 8  0              7068                               1                   3.99
#    1              7723                               1                   5.14
# 9  0             10869                               1                   3.49
#    1              7082                               2                   4.63
# 10 0              7020                               2                   3.83
#    1              7372                               2                   4.92
# 11 0              7106                               2                   3.83
#    1              7212                               2                    4.9
# 12 0             14292                               1                   3.48
#    1              7152                               2                   4.54
# 13 0              7948                               1                   3.73
#    1             11533                               1                   5.26
# 14 0              7105                               1                    3.7
#    1             10380                               1                   5.11
# 15 0             16948                               2                   3.29
#    1              9659                               3                    4.7
# 16 0              7673                               2                   3.54
#    1              7197                               2                   4.72
# 17 0             12064                               3                    2.6
#    1             11243                               4                   4.81
#
#      Начальное давление, МПа Объемный расход, м3/мин  \
# 0  0                     3.1                     727
#    1                    3.55                     336
# 1  0                    3.04                     790
#    1                    3.59                     353
# 2  0                    3.11                     654
#    1                    3.45                     312
# 3  0                     3.1                     412
#    1                    3.98                     337
# 4  0                    3.11                     394
#    1                    4.05                     318
# 5  0                    3.11                     397
#    1                    4.02                     322
# 6  0                    3.14                     372
#    1                    4.11                     298
# 7  0                    3.11                     385
#    1                    4.06                     310
# 8  0                    3.07                     420
#    1                    3.93                     344
# 9  0                    3.03                     709
#    1                    3.43                     331
# 10 0                    2.92                     424
#    1                    3.77                     345
# 11 0                     2.9                     423
#    1                    3.77                     341
# 12 0                    2.89                     781
#    1                    3.42                     348
# 13 0                    2.86                     495
#    1                    3.67                     405
# 14 0                    2.88                     470
#    1                    3.64                     391
# 15 0                     2.2                     801
#    1                    3.23                     379
# 16 0                    2.53                     428
#    1                    3.48                     326
# 17 0                    1.54                     690
#    1                    2.54                     326
#
#                             СПЧ Степень сжатия, д. ед.  \
# 0  0     ГПА-ц3-16С-45-1.7(ККМ)                   1.16
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.33
# 1  0     ГПА-ц3-16С-45-1.7(ККМ)                    1.2
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.32
# 2  0     ГПА-ц3-16С-45-1.7(ККМ)                   1.13
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.38
# 3  0     ГПА-ц3-16С-45-1.7(ККМ)                    1.3
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.29
# 4  0     ГПА-ц3-16С-45-1.7(ККМ)                   1.32
#    1  CGX-425-16-65-1.7СМП(ПСИ)                    1.3
# 5  0     ГПА-ц3-16С-45-1.7(ККМ)                   1.31
#    1  CGX-425-16-65-1.7СМП(ПСИ)                    1.3
# 6  0     ГПА-ц3-16С-45-1.7(ККМ)                   1.33
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.32
# 7  0     ГПА-ц3-16С-45-1.7(ККМ)                   1.32
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.31
# 8  0     ГПА-ц3-16С-45-1.7(ККМ)                    1.3
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.31
# 9  0     ГПА-ц3-16С-45-1.7(ККМ)                   1.15
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.35
# 10 0     ГПА-ц3-16С-45-1.7(ККМ)                   1.31
#    1  CGX-425-16-65-1.7СМП(ПСИ)                    1.3
# 11 0     ГПА-ц3-16С-45-1.7(ККМ)                   1.32
#    1  CGX-425-16-65-1.7СМП(ПСИ)                    1.3
# 12 0     ГПА-ц3-16С-45-1.7(ККМ)                   1.21
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.33
# 13 0     ГПА-ц3-16С-45-1.7(ККМ)                    1.3
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.43
# 14 0     ГПА-ц3-16С-45-1.7(ККМ)                   1.28
#    1  CGX-425-16-65-1.7СМП(ПСИ)                    1.4
# 15 0     ГПА-ц3-16С-45-1.7(ККМ)                    1.5
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.45
# 16 0     ГПА-ц3-16С-45-1.7(ККМ)                    1.4
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.36
# 17 0     ГПА-ц3-16С-45-1.7(ККМ)                   1.69
#    1  CGX-425-16-65-1.7СМП(ПСИ)                   1.89
#
#      Удаленность от точки помпажа, д. ед Частота, об/мин
# 0  0                                 100            4400
#    1                                  92            4040
# 1  0                                  99            4790
#    1                                 100            4100
# 2  0                                 100            3950
#    1                                  73            4070
# 3  0                                  48            3710
#    1                                  99            3920
# 4  0                                  43            3740
#    1                                  91            3830
# 5  0                                  45            3710
#    1                                  93            3860
# 6  0                                  38            3740
#    1                                  78            3800
# 7  0                                  41            3740
#    1                                  85            3830
# 8  0                                  50            3710
#    1                                  99            4010
# 9  0                                 100            4280
#    1                                  87            4070
# 10 0                                  50            3770
#    1                                 100            4010
# 11 0                                  49            3800
#    1                                  99            3980
# 12 0                                  98            4760
#    1                                  96            4100
# 13 0                                  63            3920
#    1                                 100            4700
# 14 0                                  61            3770
#    1                                  99            4550
# 15 0                                  81            5510
#    1                                  89            4610
# 16 0                                  41            4130
#    1                                  83            4070
# 17 0                                  60            5600
#    1                                  28            5390

# %%
df_res = pd.concat(df_conf, keys=(range(18)))
df_res.dtypes
# Out:
# power          object
# comp           object
# volume_rate    object
# udal           object
# freq           object
# freq_dimm      object
# p_in           object
# p_out          object
# title          object
# target         object
# work_gpa       object
# dtype: object

# %%
pd.concat([

    (df_res_case.unstack().loc[:,'Частота, об/мин'].astype(float) - df_res.unstack().loc[:,'freq']),
    df_res.unstack(),
    df_res_case.unstack(),

],axis=1).to_clipboard()

# %%
(df_res_case.unstack().loc[:, ('Конечное давление, МПа', 1)].astype(float) - df_res.unstack().loc[:, ('p_out', 1)]).hist()
# Out:
# <Axes: >

# %%
data_res_case = {'freq': [10, 20, 30], 'amp': [100, 200, 300]}
data_res = {'freq': [5, 15, 25], 'amp': [50, 150, 250]}

df_res_case = pd.DataFrame(data_res_case)
df_res = pd.DataFrame(data_res)
df_res.dtypes, df_res_case.dtypes

result = df_res_case - df_res

print(result)
# Out:
#    freq  amp
# 0     5   50
# 1     5   50
# 2     5   50
